# %% [markdown]
# # 1. Function
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2.
# Buat fungsi yang menggunakan dua string sebagai argumen dan mengembalikan True atau False bergantung pada apakah jumlah total karakter di string pertama sama dengan jumlah total karakter di string kedua.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3.
# Buat fungsi yang mengambil string (akan menjadi nama depan dan belakang seseorang) dan mengembalikan string dengan nama depan dan belakang ditukar.
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4.
# Buat fungsi yang mengambil daftar angka antara 1 dan 10 (tidak termasuk satu angka) dan mengembalikan angka yang hilang.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5.
# Buat fungsi yang mengambil dua string angka dan mengembalikan jumlahnya sebagai string.
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6.
# Buat fungsi yang membangun kata dari huruf acak yang ada di daftar pertama. Gunakan daftar kedua untuk menetapkan setiap posisi huruf dalam daftar pertama. Kembalikan string dari huruf yang tidak diacak (yang menyusun kata).
# ![image.png](attachment:image.png)

# %% [markdown]
# # 7.
#
# Tulis fungsi yang mengubah setiap huruf menjadi huruf berikutnya:
#
# "a" menjadi "b"
#
# "b" menjadi "c"
#
# "d" menjadi "e"
#
# dan seterusnya ...
#
# ![image.png](attachment:image.png)
#
# Tidak akan ada z dalam pengujian.

# %% [markdown]
# # 8.
# Tulis fungsi yang mengembalikan True jika dua list, saat digabungkan, membentuk urutan yang berurutan. Urutan berurutan adalah urutan tanpa celah di bilangan bulat, mis. 1, 2, 3, 4, 5 adalah urutan yang berurutan, tetapi 1, 2, 4, 5 bukan.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 9.
# Diberikan integer, buat fungsi yang mengembalikan bilangan prima berikutnya. Jika bilangan prima, kembalikan bilangan itu sendiri.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 10.
# Buat fungsi yang mengambil usia dan mengembalikan usia dalam hitungan hari.
# ![image.png](attachment:image.png)

# %% [markdown]
# # 11.
#
# Dalam tantangan ini, seorang petani meminta Anda untuk memberi tahu dia berapa banyak kaki yang dapat dihitung di antara semua hewannya. Petani membiakkan tiga spesies:
#
# ayam = 2 kaki
# sapi = 4 kaki
# babi = 4 kaki
#
# Peternak telah menghitung hewannya dan dia memberi Anda subtotal untuk setiap spesies. Anda harus mengimplementasikan fungsi yang mengembalikan jumlah total kaki semua hewan.
#
# *Ingatlah bahwa peternak ingin mengetahui jumlah total kaki dan bukan jumlah total hewan.
# ![image.png](attachment:image.png)

# %% [markdown]
# # 12.
# Buat fungsi untuk menguji apakah sebuah string adalah pin yang valid atau tidak.
#
# Pin yang valid memiliki:
# 1. Tepat 4 atau 6 karakter.
# 2. Hanya karakter numerik (0-9).
# 3. Tidak ada spasi.
# ![image.png](attachment:image.png)

# %% [markdown]
# # 13.
# Buat fungsi yang mengambil string dan mengembalikan jumlah (hitungan) vokal yang terkandung di dalamnya.
# ![image.png](attachment:image.png)

# %% [markdown]
# # 14.
# Buat fungsi yang menggunakan bilangan bulat n dan mengembalikan faktorial faktorial. Lihat contoh di bawah untuk pemahaman yang lebih baik:
# ![image.png](attachment:image.png)
